# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
file_data = r'C:\Users\TP\Desktop\CarPricePredictorInTunisia\Data\CleanedData2.csv'

df = pd.read_csv(file_data)

# %%
print(df)
# Out:
#            Brand         Model  Price  Boite vitesse  Cylindrée  \
# 0     Alfa_Romeo        Giulia  198.0           True      1.995
# 1     Alfa_Romeo       Stelvio  265.0           True      1.995
# 2           Audi  A3_Sportback  145.0           True      1.395
# 3           Audi    A3_Berline  149.0           True      1.395
# 4           Audi            A4  198.0           True      1.984
# ...          ...           ...    ...            ...        ...
# 4849   Ssangyong         Kyron   38.0           True      3.000
# 4850      Autres        Autres   50.0          False      1.600
# 4851     Peugeot           206   18.0          False      2.400
# 4852     Citroen            C4   35.0          False      1.600
# 4853  Mitsubishi        Canter   40.0          False      1.200
#
#       Puissance fiscale  Kilométrage   Age  Essence  Diesel  Electric
# 0                    11          0.0   0.0     True   False     False
# 1                    17          0.0   0.0     True   False     False
# 2                     8          0.0   0.0     True   False     False
# 3                     8          0.0   0.0     True   False     False
# 4                     8          0.0   0.0     True   False     False
# ...                 ...          ...   ...      ...     ...       ...
# 4849                 10        144.9  12.0    False    True     False
# 4850                  7        112.5  12.0     True   False     False
# 4851                  4        199.0  22.0     True   False     False
# 4852                  5        299.0  11.0    False    True     False
# 4853                  4         30.2   2.0     True   False     False
#
# [4854 rows x 11 columns]

# %%
brand_model_counts = df.groupby("Brand")["Model"].nunique()

brands_to_keep = brand_model_counts[brand_model_counts >= 9].index

df = df[df["Brand"].isin(brands_to_keep)]

# %%
# Step 1: Encode the 'Brand' column with unique integers (same as before)
brand_mapping = {brand: idx + 1 for idx, brand in enumerate(df['Brand'].unique())}
df['Brand_encoded'] = df['Brand'].map(brand_mapping)
print(brand_mapping)
print("-------")

# Step 2: Encode the 'Model' column with a hierarchical format (e.g., 1.1, 1.2, etc.)
model_mapping = {}
for brand in df['Brand'].unique():
    unique_models = df[df['Brand'] == brand]['Model'].unique()
    model_mapping_for_brand = {model: f"{brand_mapping[brand]}.{idx + 1}" for idx, model in enumerate(unique_models)}
    model_mapping[brand] = model_mapping_for_brand
print(model_mapping)
print("-------")

# Apply the model mapping to the dataframe
df['Model_encoded'] = df.apply(lambda row: model_mapping[row['Brand']][row['Model']], axis=1)

df2=df
df = df.drop('Brand', axis=1)
df = df.drop('Model', axis=1)

# Display the DataFrame with encoded columns
print(df)
# Out:
# {'Audi': 1, 'Bmw': 2, 'Chery': 3, 'Chevrolet': 4, 'Citroen': 5, 'Dfsk': 6, 'Fiat': 7, 'Ford': 8, 'Geely': 9, 'Honda': 10, 'Hyundai': 11, 'Jaguar': 12, 'Kia': 13, 'Land_Rover': 14, 'Mercedes_Benz': 15, 'Mg': 16, 'Mitsubishi': 17, 'Nissan': 18, 'Opel': 19, 'Peugeot': 20, 'Renault': 21, 'Seat': 22, 'Skoda': 23, 'Ssangyong': 24, 'Suzuki': 25, 'Toyota': 26, 'Volkswagen': 27, 'Citroën': 28, 'Mazda': 29}
# -------
# {'Audi': {'A3_Sportback': '1.1', 'A3_Berline': '1.2', 'A4': '1.3', 'A6': '1.4', 'Q2': '1.5', 'Q3': '1.6', 'Q3_Sportback': '1.7', 'Q7': '1.8', 'A5_Sportback': '1.9', 'A5_Coupé': '1.10', 'A7_Sportback': '1.11', 'Q5': '1.12', 'Q4_E_Tron': '1.13', 'A5_Cabriolet': '1.14', 'Q5_Sportback': '1.15', 'Q8': '1.16', 'A3': '1.17', 'Rs5': '1.18', 'A1_Sportback': '1.19', 'A5': '1.20', 'A1': '1.21'}, 'Bmw': {'Serie_1_5p': '2.1', 'Serie_2_Gran_Coupe': '2.2', 'Serie_3': '2.3', 'Serie_4_Gran_Coupe': '2.4', 'Serie_4_Coupe': '2.5', 'Serie_5': '2.6', 'Serie_7': '2.7', 'X1': '2.8', 'X1_Hybride': '2.9', 'X2': '2.10', 'X3_Hybride_Rechargeable': '2.11', 'X4': '2.12', 'X5_Hybride': '2.13', 'Série_4_Gran_Coupé': '2.14', 'X6': '2.15', 'Série_5': '2.16', 'Série_3': '2.17', 'Série_3_Coupé': '2.18', 'Série_7': '2.19', 'X5': '2.20', 'Série_1': '2.21', 'X3': '2.22', 'Série_4_Coupé': '2.23', 'Série_6': '2.24', 'Série_2_Gran_Coupé': '2.25', 'M3': '2.26', 'Série_3_Gt': '2.27', 'Serie_3_Gt': '2.28', 'Serie_1': '2.29', 'Serie_4': '2.30', 'Serie_6': '2.31', 'Serie_2': '2.32'}, 'Chery': {'Tiggo_1x_Populaire': '3.1', 'Tiggo_3x': '3.2', 'Arrizo_5': '3.3', 'Tiggo_7': '3.4', 'Tiggo_8_Pro': '3.5', 'Tiggo_7_Pro': '3.6', 'E3': '3.7', 'Tiggo_8': '3.8', 'Tiggo_2': '3.9', 'Tiggo_3': '3.10', 'Qq': '3.11', 'Tiggo': '3.12', 'Qq6': '3.13', 'A5': '3.14', 'A516': '3.15', 'A3': '3.16'}, 'Chevrolet': {'Groove': '4.1', 'Captiva': '4.2', 'Equinox': '4.3', 'Sonic': '4.4', 'Sonic_4p': '4.5', 'Cruze': '4.6', 'Aveo': '4.7', 'Spark': '4.8', 'Alero': '4.9', 'Suburban': '4.10', 'S_10': '4.11', 'Corvette_Cabrio': '4.12'}, 'Citroen': {'C3_Populaire': '5.1', 'C4_X': '5.2', 'Berlingo_Van': '5.3', 'Jumpy_Fourgon': '5.4', 'Jumper': '5.5', 'Berlingo_Multispace': '5.6', 'C_Elysée': '5.7', 'C1': '5.8', 'Berlingo': '5.9', 'C3': '5.10', 'Nemo': '5.11', 'Ds5': '5.12', 'C4': '5.13', 'C4_Cactus': '5.14', 'Ds3': '5.15', 'C5': '5.16', 'C35': '5.17', 'Ds': '5.18', 'C4_Aircross': '5.19', 'Ds4': '5.20', 'Saxo': '5.21', 'C4_Picasso': '5.22', 'C25': '5.23', 'Jumpy': '5.24', 'Xsara_Picasso': '5.25', 'C15': '5.26', 'Ds23': '5.27'}, 'Dfsk': {'Glory_500': '6.1', 'Glory_580': '6.2', 'Glory_Ix5': '6.3', 'K01s': '6.4', 'K01h': '6.5', 'K02s': '6.6', 'C31': '6.7', 'C32': '6.8', 'K01': '6.9'}, 'Fiat': {'Tipo_Berline': '7.1', '500': '7.2', 'Fiorino_Combi': '7.3', 'Doblo': '7.4', 'Ducato': '7.5', 'Siena': '7.6', 'Strada': '7.7', 'Fiorino': '7.8', 'Tipo_5_Portes': '7.9', 'Punto': '7.10', '500x': '7.11', 'Panda_City_Cross': '7.12', 'Grande_Punto': '7.13', 'Bravo': '7.14', 'Qubo': '7.15', 'Panda': '7.16', 'Linea': '7.17', 'Palio': '7.18', 'Tipo': '7.19', '500c': '7.20', 'Tempra': '7.21', '500l': '7.22', 'Ulysse': '7.23', 'Uno': '7.24', 'Scudo': '7.25'}, 'Ford': {'Everest': '8.1', 'Ranger': '8.2', 'Ranger_Raptor': '8.3', 'Transit_Van': '8.4', 'Transit_Bus': '8.5', 'Fiesta': '8.6', 'Fusion': '8.7', 'Focus': '8.8', 'Ecosport': '8.9', 'Kuga': '8.10', 'Transit_Custom': '8.11', 'Figo': '8.12', 'Mondeo': '8.13', 'Autre': '8.14', 'Ka': '8.15', 'Puma': '8.16', 'Escort': '8.17', 'Transit': '8.18', 'C_Max': '8.19', 'Focus_C_Max': '8.20', 'Ford.fiesta': '8.21', 'Escape': '8.22'}, 'Geely': {'Gx3_Pro': '9.1', 'Coolray': '9.2', 'Azkara': '9.3', 'Gc6': '9.4', 'Gx3': '9.5', 'Gk_Gt': '9.6', 'Lc': '9.7', 'Gk_Gs': '9.8', 'Gk_Gl': '9.9', 'Mk_Gl': '9.10'}, 'Honda': {'Jazz': '10.1', 'Hr_V': '10.2', 'Zr_V': '10.3', 'City': '10.4', 'Civic': '10.5', 'Civic_Hybride': '10.6', 'Civic_Type_R': '10.7', 'Accord': '10.8', 'Cr_V': '10.9', 'Brio_Amaze': '10.10'}, 'Hyundai': {'Grand_I10_Populaire': '11.1', 'Grand_I10': '11.2', 'Grand_I10_Sedan': '11.3', 'I20': '11.4', 'Venue': '11.5', 'Creta': '11.6', 'Kona_Hybride': '11.7', 'Kona': '11.8', 'Tucson': '11.9', 'Tucson_Hybride': '11.10', 'Azera_Hybride': '11.11', 'Santa_Fe': '11.12', 'Palisade_Calligraphy': '11.13', 'Staria': '11.14', 'Staria_9_Places': '11.15', 'H_1': '11.16', 'Autre': '11.17', 'Coupe': '11.18', 'I30_Fastback': '11.19', 'Veloster': '11.20', 'Ix35': '11.21', 'Solaris': '11.22', 'I_10': '11.23', 'I_20 ...
# -------
#       Price  Boite vitesse  Cylindrée  Puissance fiscale  Kilométrage   Age  \
# 2     145.0           True      1.395                  8          0.0   0.0
# 3     149.0           True      1.395                  8          0.0   0.0
# 4     198.0           True      1.984                  8          0.0   0.0
# 5     295.0           True      1.984                 11          0.0   0.0
# 6     159.0           True      1.498                  8          0.0   0.0
# ...     ...            ...        ...                ...          ...   ...
# 4848   76.0           True      1.400                  7         41.0   3.0
# 4849   38.0           True      3.000                 10        144.9  12.0
# 4851   18.0          False      2.400                  4        199.0  22.0
# 4852   35.0          False      1.600                  5        299.0  11.0
# 4853   40.0          False      1.200                  4         30.2   2.0
#
#       Essence  Diesel  Electric  Brand_encoded Model_encoded
# 2        True   False     False              1           1.1
# 3        True   False     False              1           1.2
# 4        True   False     False              1           1.3
# 5        True   False      True              1           1.4
# 6        True   False     False              1           1.5
# ...       ...     ...       ...            ...           ...
# 4848     True   False     False             20          20.2
# 4849    False    True     False             24          24.7
# 4851     True   False     False             20         20.31
# 4852    False    True     False              5          5.13
# 4853     True   False     False             17         17.13
#
# [4391 rows x 11 columns]

# %%
# Re-define X and Y after cleaning the data
X = df.drop(columns=['Price'])
Y = df['Price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\tp\anaconda3\envs\ml\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy in c:\users\tp\anaconda3\envs\ml\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\tp\anaconda3\envs\ml\lib\site-packages (from xgboost) (1.10.1)

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import numpy as np

scaler = StandardScaler()

# Scale the features
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize XGBoost regressor
model = XGBRegressor(
    n_estimators=100,  # Number of trees
    max_depth=3,       # Depth of trees
    learning_rate=0.1, # Step size for updates
    subsample=0.8,     # Fraction of samples used for training
    colsample_bytree=0.8,  # Fraction of features used for each tree
    random_state=42    # Reproducibility
)

# Train the model
model.fit(X_train_scaled, Y_train)

# Predict on the test set
Y_pred = model.predict(X_test_scaled)

# Calculate metrics
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, Y_pred)

print(f"XGBoost Model")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
print("-----------")
# Out:
# XGBoost Model
# Mean Absolute Error (MAE): 17.69
# Mean Squared Error (MSE): 2259.19
# R-squared (R²): 0.67
# -----------

# %%
# Reverse the brand and model mappings for decoding
brand_reverse_mapping = {v: k for k, v in brand_mapping.items()}
model_reverse_mapping = {f"{brand_mapping[brand]}.{idx + 1}": model for brand in df2['Brand'].unique() for idx, model in enumerate(df2[df2['Brand'] == brand]['Model'].unique())}

# Before scaling and transforming, save the indices of the original X_test
X_test_indices = X_test.index

# Use the transformed data for predictions
for i in range(len(Y_pred)):
    diff = abs(Y_test.iloc[i] - Y_pred[i])

    # Only print when the difference is greater than 10
    if diff > 10:
        # Decode the Brand and Model from the encoded values
        brand_name = brand_reverse_mapping[X_test.loc[X_test_indices[i], 'Brand_encoded']]
        model_name = model_reverse_mapping[str(X_test.loc[X_test_indices[i], 'Model_encoded'])]

        car_features = X_test.loc[X_test_indices[i]].drop(['Brand_encoded', 'Model_encoded'])
        # Flatten the car features
        car_info = ", ".join([f"{col}: {value}" for col, value in car_features.items()])

        print(f"The car is: Brand - {brand_name}, Model - {model_name}")  # Display decoded brand and model
        print(f"Features: {car_info}")
        print(f"Predicted price: {Y_pred[i]} | Real price: {Y_test.iloc[i]} | diff: {diff}")
        print("-------")
# Out:
# The car is: Brand - Peugeot, Model - 508
# Features: Boite vitesse: True, Cylindrée: 2.2, Puissance fiscale: 12, Kilométrage: 180.0, Age: 12.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 70.16060638427734 | Real price: 42.0 | diff: 28.160606384277344
# -------
# The car is: Brand - Toyota, Model - Yaris_Cross
# Features: Boite vitesse: True, Cylindrée: 1.49, Puissance fiscale: 5, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 100.1814193725586 | Real price: 119.9 | diff: 19.718580627441412
# -------
# The car is: Brand - Toyota, Model - Yaris_Verso
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 4, Kilométrage: 200.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 43.03805923461914 | Real price: 31.5 | diff: 11.53805923461914
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Sport
# Features: Boite vitesse: True, Cylindrée: 3.0, Puissance fiscale: 24, Kilométrage: 96.0, Age: 8.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 247.7752685546875 | Real price: 208.0 | diff: 39.7752685546875
# -------
# The car is: Brand - Chery, Model - Tiggo
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 8, Kilométrage: 13.5, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 72.93108367919922 | Real price: 41.0 | diff: 31.93108367919922
# -------
# The car is: Brand - Ssangyong, Model - Actyon
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 7, Kilométrage: 210.0, Age: 6.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 55.85316467285156 | Real price: 45.0 | diff: 10.853164672851562
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_Cla
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 120.0, Age: 4.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 119.32617950439453 | Real price: 158.0 | diff: 38.67382049560547
# -------
# The car is: Brand - Nissan, Model - Qashqai
# Features: Boite vitesse: True, Cylindrée: 1.3, Puissance fiscale: 6, Kilométrage: 41.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 67.66616821289062 | Real price: 83.0 | diff: 15.333831787109375
# -------
# The car is: Brand - Peugeot, Model - Partner
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 5, Kilométrage: 76.0, Age: 4.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 64.89321899414062 | Real price: 81.0 | diff: 16.106781005859375
# -------
# The car is: Brand - Hyundai, Model - Grand_I10
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 100.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.35912322998047 | Real price: 44.5 | diff: 14.859123229980469
# -------
# The car is: Brand - Mercedes_Benz, Model - Gla
# Features: Boite vitesse: True, Cylindrée: 1.595, Puissance fiscale: 8, Kilométrage: 104.0, Age: 9.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 109.83805847167969 | Real price: 95.0 | diff: 14.838058471679688
# -------
# The car is: Brand - Kia, Model - Picanto
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 4, Kilométrage: 62.0, Age: 4.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 53.064483642578125 | Real price: 38.0 | diff: 15.064483642578125
# -------
# The car is: Brand - Renault, Model - Megane
# Features: Boite vitesse: False, Cylindrée: 1.332, Puissance fiscale: 8, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 108.6619644165039 | Real price: 94.95 | diff: 13.711964416503903
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_Clc
# Features: Boite vitesse: False, Cylindrée: 2.2, Puissance fiscale: 11, Kilométrage: 200.0, Age: 15.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 60.28599548339844 | Real price: 40.0 | diff: 20.285995483398438
# -------
# The car is: Brand - Citroen, Model - C4_Cactus
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 6, Kilométrage: 135.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 52.83212661743164 | Real price: 40.0 | diff: 12.83212661743164
# -------
# The car is: Brand - Bmw, Model - Série_5
# Features: Boite vitesse: True, Cylindrée: 1.995, Puissance fiscale: 9, Kilométrage: 356.0, Age: 16.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 52.227439880371094 | Real price: 42.0 | diff: 10.227439880371094
# -------
# The car is: Brand - Nissan, Model - Micra
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 130.0, Age: 7.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 48.56550598144531 | Real price: 29.5 | diff: 19.065505981445312
# -------
# The car is: Brand - Peugeot, Model - Boxer
# Features: Boite vitesse: False, Cylindrée: 1.219, Puissance fiscale: 7, Kilométrage: 200.1, Age: 17.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 27.802610397338867 | Real price: 14.0 | diff: 13.802610397338867
# -------
# The car is: Brand - Mercedes_Benz, Model - Gle_Coupé
# Features: Boite vitesse: True, Cylindrée: 3.5, Puissance fiscale: 8, Kilométrage: 74.0, Age: 3.0, Essence: False, Diesel: True, Electric: True
# Predicted price: 282.46331787109375 | Real price: 375.0 | diff: 92.53668212890625
# -------
# The car is: Brand - Citroen, Model - C3
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 4, Kilométrage: 130.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 35.4534912109375 | Real price: 387.654 | diff: 352.2005087890625
# -------
# The car is: Brand - Renault, Model - Espace
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 9, Kilométrage: 280.0, Age: 17.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 45.8581428527832 | Real price: 220.0 | diff: 174.1418571472168
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Evoque
# Features: Boite vitesse: True, Cylindrée: 1.998, Puissance fiscale: 10, Kilométrage: 130.0, Age: 9.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 106.12811279296875 | Real price: 139.0 | diff: 32.87188720703125
# -------
# The car is: Brand - Audi, Model - A6
# Features: Boite vitesse: True, Cylindrée: 3.0, Puissance fiscale: 15, Kilométrage: 200.0, Age: 16.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 76.18559265136719 | Real price: 49.0 | diff: 27.185592651367188
# -------
# The car is: Brand - Bmw, Model - Serie_3
# Features: Boite vitesse: True, Cylindrée: 1.598, Puissance fiscale: 9, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 212.59423828125 | Real price: 249.9 | diff: 37.305761718750006
# -------
# The car is: Brand - Renault, Model - Clio
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 4, Kilométrage: 200.0, Age: 16.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 19.08082389831543 | Real price: 123.456 | diff: 104.37517610168457
# -------
# The car is: Brand - Suzuki, Model - Baleno
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 160.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 52.2349739074707 | Real price: 40.0 | diff: 12.234973907470703
# -------
# The car is: Brand - Mazda, Model - 2
# Features: Boite vitesse: False, Cylindrée: 1.5, Puissance fiscale: 6, Kilométrage: 183.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 49.14244842529297 | Real price: 35.5 | diff: 13.642448425292969
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Sport
# Features: Boite vitesse: True, Cylindrée: 2.996, Puissance fiscale: 29, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 617.9322509765625 | Real price: 607.2 | diff: 10.732250976562455
# -------
# The car is: Brand - Hyundai, Model - I20
# Features: Boite vitesse: False, Cylindrée: 1.197, Puissance fiscale: 4, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 52.20562744140625 | Real price: 72.95 | diff: 20.744372558593753
# -------
# The car is: Brand - Mercedes_Benz, Model - Gla
# Features: Boite vitesse: True, Cylindrée: 1.332, Puissance fiscale: 9, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 193.45504760742188 | Real price: 221.0 | diff: 27.544952392578125
# -------
# The car is: Brand - Opel, Model - Gt
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 40.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 52.391788482666016 | Real price: 62.9 | diff: 10.508211517333983
# -------
# The car is: Brand - Citroen, Model - C3_Populaire
# Features: Boite vitesse: False, Cylindrée: 1.199, Puissance fiscale: 4, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 46.06060791015625 | Real price: 34.626 | diff: 11.434607910156252
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_A
# Features: Boite vitesse: True, Cylindrée: 1.332, Puissance fiscale: 9, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 193.07492065429688 | Real price: 172.0 | diff: 21.074920654296875
# -------
# The car is: Brand - Toyota, Model - Land_Cruiser_76
# Features: Boite vitesse: False, Cylindrée: 4.164, Puissance fiscale: 11, Kilométrage: 0.0, Age: 0.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 270.11669921875 | Real price: 224.998 | diff: 45.11869921875001
# -------
# The car is: Brand - Mazda, Model - Bt_50
# Features: Boite vitesse: False, Cylindrée: 2.0, Puissance fiscale: 9, Kilométrage: 124.0, Age: 7.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 79.3076400756836 | Real price: 65.0 | diff: 14.307640075683594
# -------
# The car is: Brand - Seat, Model - Leon
# Features: Boite vitesse: False, Cylindrée: 1.197, Puissance fiscale: 6, Kilométrage: 118.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 50.0688591003418 | Real price: 62.0 | diff: 11.931140899658203
# -------
# The car is: Brand - Mercedes_Benz, Model - Eqa
# Features: Boite vitesse: True, Cylindrée: 0.899, Puissance fiscale: 7, Kilométrage: 98.0, Age: 2.0, Essence: False, Diesel: False, Electric: False
# Predicted price: 125.50880432128906 | Real price: 149.0 | diff: 23.491195678710938
# -------
# The car is: Brand - Hyundai, Model - Palisade_Calligraphy
# Features: Boite vitesse: True, Cylindrée: 2.199, Puissance fiscale: 12, Kilométrage: 0.0, Age: 0.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 296.12890625 | Real price: 350.0 | diff: 53.87109375
# -------
# The car is: Brand - Nissan, Model - Qashqai
# Features: Boite vitesse: False, Cylindrée: 1.5, Puissance fiscale: 6, Kilométrage: 100.0, Age: 3.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 66.86117553710938 | Real price: 86.0 | diff: 19.138824462890625
# -------
# The car is: Brand - Mercedes_Benz, Model - Glc_Coupe
# Features: Boite vitesse: True, Cylindrée: 1.999, Puissance fiscale: 12, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 365.8794250488281 | Real price: 349.0 | diff: 16.879425048828125
# -------
# The car is: Brand - Bmw, Model - Serie_5
# Features: Boite vitesse: True, Cylindrée: 2.5, Puissance fiscale: 11, Kilométrage: 390.0, Age: 19.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 65.01664733886719 | Real price: 29.5 | diff: 35.51664733886719
# -------
# The car is: Brand - Mercedes_Benz, Model - Cla
# Features: Boite vitesse: True, Cylindrée: 1.461, Puissance fiscale: 6, Kilométrage: 60.0, Age: 3.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 127.7977294921875 | Real price: 145.0 | diff: 17.2022705078125
# -------
# The car is: Brand - Land_Rover, Model - Defender
# Features: Boite vitesse: True, Cylindrée: 1.997, Puissance fiscale: 21, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 401.95281982421875 | Real price: 413.0 | diff: 11.04718017578125
# -------
# The car is: Brand - Fiat, Model - Fiorino
# Features: Boite vitesse: False, Cylindrée: 1.3, Puissance fiscale: 5, Kilométrage: 110.0, Age: 4.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 54.13471603393555 | Real price: 35.0 | diff: 19.134716033935547
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C
# Features: Boite vitesse: True, Cylindrée: 1.496, Puissance fiscale: 9, Kilométrage: 2.74, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 193.45504760742188 | Real price: 229.0 | diff: 35.544952392578125
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C
# Features: Boite vitesse: True, Cylindrée: 1.595, Puissance fiscale: 8, Kilométrage: 125.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 120.3907699584961 | Real price: 103.0 | diff: 17.390769958496094
# -------
# The car is: Brand - Volkswagen, Model - Golf_7
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 13, Kilométrage: 73.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 139.55645751953125 | Real price: 115.0 | diff: 24.55645751953125
# -------
# The car is: Brand - Hyundai, Model - Tucson_Hybride
# Features: Boite vitesse: True, Cylindrée: 1.598, Puissance fiscale: 7, Kilométrage: 109.0, Age: 3.0, Essence: False, Diesel: True, Electric: True
# Predicted price: 147.05072021484375 | Real price: 120.0 | diff: 27.05072021484375
# -------
# The car is: Brand - Ford, Model - Ecosport
# Features: Boite vitesse: True, Cylindrée: 1.0, Puissance fiscale: 7, Kilométrage: 151.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 67.40097045898438 | Real price: 55.0 | diff: 12.400970458984375
# -------
# The car is: Brand - Kia, Model - C'eed
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 9, Kilométrage: 4.55, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 151.96856689453125 | Real price: 70.0 | diff: 81.96856689453125
# -------
# The car is: Brand - Mercedes_Benz, Model - Glc
# Features: Boite vitesse: True, Cylindrée: 2.499, Puissance fiscale: 12, Kilométrage: 115.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 149.81410217285156 | Real price: 169.0 | diff: 19.185897827148438
# -------
# The car is: Brand - Mg, Model - Hs
# Features: Boite vitesse: True, Cylindrée: 1.998, Puissance fiscale: 15, Kilométrage: 35.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 176.6044464111328 | Real price: 103.0 | diff: 73.60444641113281
# -------
# The car is: Brand - Nissan, Model - Qashqai
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 9, Kilométrage: 90.0, Age: 8.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 79.15391540527344 | Real price: 69.0 | diff: 10.153915405273438
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_Gl
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 8, Kilométrage: 83.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 153.0758514404297 | Real price: 178.0 | diff: 24.924148559570312
# -------
# The car is: Brand - Toyota, Model - Agya
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 64.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 68.3589859008789 | Real price: 37.5 | diff: 30.858985900878906
# -------
# The car is: Brand - Renault, Model - Clio
# Features: Boite vitesse: False, Cylindrée: 1.5, Puissance fiscale: 5, Kilométrage: 110.0, Age: 4.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 57.23886489868164 | Real price: 45.5 | diff: 11.73886489868164
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 6, Kilométrage: 228.0, Age: 27.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 30.31281280517578 | Real price: 11.5 | diff: 18.81281280517578
# -------
# The car is: Brand - Bmw, Model - Série_7
# Features: Boite vitesse: True, Cylindrée: 2.998, Puissance fiscale: 20, Kilométrage: 200.0, Age: 12.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 105.36361694335938 | Real price: 155.5 | diff: 50.136383056640625
# -------
# The car is: Brand - Mazda, Model - Bt_50
# Features: Boite vitesse: False, Cylindrée: 3.0, Puissance fiscale: 10, Kilométrage: 300.0, Age: 15.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 31.838821411132812 | Real price: 42.0 | diff: 10.161178588867188
# -------
# The car is: Brand - Volkswagen, Model - Golf_6
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 5, Kilométrage: 148.0, Age: 16.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 33.39769744873047 | Real price: 45.0 | diff: 11.602302551269531
# -------
# The car is: Brand - Peugeot, Model - 508
# Features: Boite vitesse: True, Cylindrée: 1.598, Puissance fiscale: 9, Kilométrage: 120.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 78.74832153320312 | Real price: 47.0 | diff: 31.748321533203125
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_E
# Features: Boite vitesse: True, Cylindrée: 3.0, Puissance fiscale: 15, Kilométrage: 60.0, Age: 12.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 146.93173217773438 | Real price: 110.0 | diff: 36.931732177734375
# -------
# The car is: Brand - Audi, Model - A4
# Features: Boite vitesse: True, Cylindrée: 1.799, Puissance fiscale: 7, Kilométrage: 143.0, Age: 8.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 73.27962493896484 | Real price: 58.0 | diff: 15.279624938964844
# -------
# The car is: Brand - Peugeot, Model - 3008
# Features: Boite vitesse: False, Cylindrée: 3.0, Puissance fiscale: 7, Kilométrage: 150.0, Age: 4.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 68.57125854492188 | Real price: 86.0 | diff: 17.428741455078125
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 5, Kilométrage: 92.5, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.62820053100586 | Real price: 42.5 | diff: 17.12820053100586
# -------
# The car is: Brand - Suzuki, Model - Swift
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 83.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 60.669715881347656 | Real price: 47.0 | diff: 13.669715881347656
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 5, Kilométrage: 7.087, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 65.79467010498047 | Real price: 820.0 | diff: 754.2053298950195
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_A
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 6, Kilométrage: 245.0, Age: 10.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 70.63111877441406 | Real price: 54.0 | diff: 16.631118774414062
# -------
# The car is: Brand - Bmw, Model - X4
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 10, Kilométrage: 140.0, Age: 6.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 127.39752960205078 | Real price: 139.0 | diff: 11.602470397949219
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 4, Kilométrage: 185.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 48.69657516479492 | Real price: 35.5 | diff: 13.196575164794922
# -------
# The car is: Brand - Bmw, Model - X5
# Features: Boite vitesse: True, Cylindrée: 2.998, Puissance fiscale: 16, Kilométrage: 295.0, Age: 17.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 84.28150177001953 | Real price: 65.0 | diff: 19.28150177001953
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_E
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 9, Kilométrage: 55.001, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 138.7340850830078 | Real price: 165.0 | diff: 26.265914916992188
# -------
# The car is: Brand - Ssangyong, Model - Musso
# Features: Boite vitesse: False, Cylindrée: 2.157, Puissance fiscale: 7, Kilométrage: 0.0, Age: 0.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 88.29420471191406 | Real price: 136.845 | diff: 48.550795288085936
# -------
# The car is: Brand - Geely, Model - Gx3
# Features: Boite vitesse: True, Cylindrée: 1.498, Puissance fiscale: 6, Kilométrage: 46.6, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 70.28092956542969 | Real price: 54.0 | diff: 16.280929565429688
# -------
# The car is: Brand - Chery, Model - Qq
# Features: Boite vitesse: True, Cylindrée: 1.0, Puissance fiscale: 4, Kilométrage: 34.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 43.6195182800293 | Real price: 21.0 | diff: 22.619518280029297
# -------
# The car is: Brand - Ford, Model - Ecosport
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 6, Kilométrage: 29.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 55.20663070678711 | Real price: 78.0 | diff: 22.79336929321289
# -------
# The car is: Brand - Dfsk, Model - K02s
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 5, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 51.5197868347168 | Real price: 39.9 | diff: 11.619786834716798
# -------
# The car is: Brand - Ssangyong, Model - Tivoli
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 7, Kilométrage: 171.0, Age: 8.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.574256896972656 | Real price: 47.5 | diff: 12.074256896972656
# -------
# The car is: Brand - Ford, Model - Autre
# Features: Boite vitesse: False, Cylindrée: 5.0, Puissance fiscale: 5, Kilométrage: 157.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 68.68856811523438 | Real price: 35.0 | diff: 33.688568115234375
# -------
# The car is: Brand - Renault, Model - Clio
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 5, Kilométrage: 85.0, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 48.22068405151367 | Real price: 27.0 | diff: 21.220684051513672
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Sport
# Features: Boite vitesse: True, Cylindrée: 3.0, Puissance fiscale: 24, Kilométrage: 190.0, Age: 9.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 217.40179443359375 | Real price: 200.0 | diff: 17.40179443359375
# -------
# The car is: Brand - Bmw, Model - Série_5
# Features: Boite vitesse: True, Cylindrée: 1.597, Puissance fiscale: 10, Kilométrage: 97.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 108.66169738769531 | Real price: 120.0 | diff: 11.338302612304688
# -------
# The car is: Brand - Skoda, Model - Octavia
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 8, Kilométrage: 230.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 77.15727233886719 | Real price: 55.0 | diff: 22.157272338867188
# -------
# The car is: Brand - Audi, Model - A6
# Features: Boite vitesse: True, Cylindrée: 1.8, Puissance fiscale: 10, Kilométrage: 124.0, Age: 8.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 88.61669158935547 | Real price: 102.0 | diff: 13.383308410644531
# -------
# The car is: Brand - Volkswagen, Model - Golf_7
# Features: Boite vitesse: True, Cylindrée: 1.198, Puissance fiscale: 7, Kilométrage: 133.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 75.9083251953125 | Real price: 63.0 | diff: 12.9083251953125
# -------
# The car is: Brand - Citroen, Model - Jumper
# Features: Boite vitesse: False, Cylindrée: 2.0, Puissance fiscale: 7, Kilométrage: 300.0, Age: 10.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 32.34635925292969 | Real price: 17.0 | diff: 15.346359252929688
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Sport
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 19, Kilométrage: 100.0, Age: 5.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 293.05682373046875 | Real price: 340.0 | diff: 46.94317626953125
# -------
# The car is: Brand - Citroen, Model - Berlingo
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 6, Kilométrage: 114.0, Age: 5.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 71.45718383789062 | Real price: 39.5 | diff: 31.957183837890625
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 9, Kilométrage: 192.0, Age: 14.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 72.88084411621094 | Real price: 51.0 | diff: 21.880844116210938
# -------
# The car is: Brand - Audi, Model - Q3
# Features: Boite vitesse: False, Cylindrée: 2.0, Puissance fiscale: 8, Kilométrage: 158.0, Age: 11.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 51.858299255371094 | Real price: 75.0 | diff: 23.141700744628906
# -------
# The car is: Brand - Hyundai, Model - I_10
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 77.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 48.62737274169922 | Real price: 34.0 | diff: 14.627372741699219
# -------
# The car is: Brand - Kia, Model - Stonic
# Features: Boite vitesse: False, Cylindrée: 1.197, Puissance fiscale: 5, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.2677001953125 | Real price: 77.98 | diff: 18.712299804687504
# -------
# The car is: Brand - Mercedes_Benz, Model - Gla
# Features: Boite vitesse: True, Cylindrée: 1.332, Puissance fiscale: 9, Kilométrage: 91.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 140.37451171875 | Real price: 182.0 | diff: 41.62548828125
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_E
# Features: Boite vitesse: True, Cylindrée: 1.998, Puissance fiscale: 10, Kilométrage: 37.0, Age: 3.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 248.4359588623047 | Real price: 260.0 | diff: 11.564041137695312
# -------
# The car is: Brand - Skoda, Model - Octavia_Rs
# Features: Boite vitesse: True, Cylindrée: 1.984, Puissance fiscale: 14, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 242.84019470214844 | Real price: 195.0 | diff: 47.84019470214844
# -------
# The car is: Brand - Nissan, Model - Qashqai
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 6, Kilométrage: 97.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 60.671409606933594 | Real price: 73.0 | diff: 12.328590393066406
# -------
# The car is: Brand - Citroën, Model - Jumpy_Fourgon
# Features: Boite vitesse: False, Cylindrée: 1.998, Puissance fiscale: 7, Kilométrage: 170.0, Age: 5.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 75.79438018798828 | Real price: 65.0 | diff: 10.794380187988281
# -------
# The car is: Brand - Suzuki, Model - Jimny
# Features: Boite vitesse: False, Cylindrée: 1.462, Puissance fiscale: 6, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 63.43525695800781 | Real price: 99.9 | diff: 36.46474304199219
# -------
# The car is: Brand - Citroen, Model - Berlingo_Multispace
# Features: Boite vitesse: False, Cylindrée: 1.56, Puissance fiscale: 5, Kilométrage: 0.0, Age: 0.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 80.33228302001953 | Real price: 103.9 | diff: 23.567716979980474
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Sport
# Features: Boite vitesse: True, Cylindrée: 2.993, Puissance fiscale: 17, Kilométrage: 197.0, Age: 11.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 127.2732162475586 | Real price: 145.0 | diff: 17.726783752441406
# -------
# The car is: Brand - Mazda, Model - Bt_50
# Features: Boite vitesse: False, Cylindrée: 2.2, Puissance fiscale: 9, Kilométrage: 70.0, Age: 11.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 75.14836120605469 | Real price: 45.0 | diff: 30.148361206054688
# -------
# The car is: Brand - Chery, Model - Tiggo
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 8, Kilométrage: 90.0, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 90.69164276123047 | Real price: 50.0 | diff: 40.69164276123047
# -------
# The car is: Brand - Toyota, Model - Aygo
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 4, Kilométrage: 1.5, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 52.94932556152344 | Real price: 39.8 | diff: 13.14932556152344
# -------
# The car is: Brand - Audi, Model - A3
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 6, Kilométrage: 240.0, Age: 14.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 51.06029510498047 | Real price: 35.0 | diff: 16.06029510498047
# -------
# The car is: Brand - Fiat, Model - Fiorino
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 120.0, Age: 3.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 53.31059646606445 | Real price: 35.0 | diff: 18.310596466064453
# -------
# The car is: Brand - Hyundai, Model - Ix35
# Features: Boite vitesse: True, Cylindrée: 1.699, Puissance fiscale: 11, Kilométrage: 160.0, Age: 8.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 94.40641784667969 | Real price: 63.5 | diff: 30.906417846679688
# -------
# The car is: Brand - Volkswagen, Model - Golf
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 6, Kilométrage: 65.399, Age: 4.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 65.13581848144531 | Real price: 111.111 | diff: 45.97518151855469
# -------
# The car is: Brand - Toyota, Model - Hilux
# Features: Boite vitesse: True, Cylindrée: 2.4, Puissance fiscale: 8, Kilométrage: 65.0, Age: 1.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 157.38282775878906 | Real price: 200.0 | diff: 42.61717224121094
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_E
# Features: Boite vitesse: True, Cylindrée: 2.198, Puissance fiscale: 11, Kilométrage: 189.0, Age: 15.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 76.99053955078125 | Real price: 63.9 | diff: 13.090539550781251
# -------
# The car is: Brand - Fiat, Model - 500c
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 4, Kilométrage: 72.0, Age: 4.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 55.513763427734375 | Real price: 45.0 | diff: 10.513763427734375
# -------
# The car is: Brand - Ford, Model - Kuga
# Features: Boite vitesse: True, Cylindrée: 1.498, Puissance fiscale: 11, Kilométrage: 208.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 93.91024780273438 | Real price: 65.0 | diff: 28.910247802734375
# -------
# The car is: Brand - Mg, Model - Hs
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 9, Kilométrage: 17.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 120.36468505859375 | Real price: 97.0 | diff: 23.36468505859375
# -------
# The car is: Brand - Mg, Model - Zs
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 9, Kilométrage: 112.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 73.8390884399414 | Real price: 56.0 | diff: 17.839088439941406
# -------
# The car is: Brand - Chery, Model - Tiggo
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 9, Kilométrage: 19.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 115.47682189941406 | Real price: 85.0 | diff: 30.476821899414062
# -------
# The car is: Brand - Chery, Model - A5
# Features: Boite vitesse: False, Cylindrée: 4.0, Puissance fiscale: 5, Kilométrage: 8.7, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 76.092041015625 | Real price: 52.0 | diff: 24.092041015625
# -------
# The car is: Brand - Citroen, Model - Berlingo
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 6, Kilométrage: 350.0, Age: 13.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 30.373403549194336 | Real price: 18.9 | diff: 11.473403549194337
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 90.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.62820053100586 | Real price: 38.5 | diff: 21.12820053100586
# -------
# The car is: Brand - Hyundai, Model - Veloster
# Features: Boite vitesse: True, Cylindrée: 1.591, Puissance fiscale: 8, Kilométrage: 80.0, Age: 12.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 71.89156341552734 | Real price: 45.0 | diff: 26.891563415527344
# -------
# The car is: Brand - Fiat, Model - Doblo
# Features: Boite vitesse: False, Cylindrée: 1.3, Puissance fiscale: 5, Kilométrage: 132.0, Age: 4.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 49.12588119506836 | Real price: 35.0 | diff: 14.12588119506836
# -------
# The car is: Brand - Chery, Model - Tiggo
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 9, Kilométrage: 60.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 90.30951690673828 | Real price: 73.0 | diff: 17.30951690673828
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Velar
# Features: Boite vitesse: True, Cylindrée: 1.998, Puissance fiscale: 15, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 362.1541748046875 | Real price: 396.5 | diff: 34.3458251953125
# -------
# The car is: Brand - Audi, Model - A5
# Features: Boite vitesse: True, Cylindrée: 1.4, Puissance fiscale: 8, Kilométrage: 124.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 90.49600982666016 | Real price: 112.0 | diff: 21.503990173339844
# -------
# The car is: Brand - Skoda, Model - Fabia
# Features: Boite vitesse: False, Cylindrée: 0.999, Puissance fiscale: 4, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 50.98347091674805 | Real price: 71.48 | diff: 20.496529083251957
# -------
# The car is: Brand - Audi, Model - A6
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 11, Kilométrage: 39.452, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 201.41976928710938 | Real price: 215.0 | diff: 13.580230712890625
# -------
# The car is: Brand - Ford, Model - Fusion
# Features: Boite vitesse: False, Cylindrée: 1.5, Puissance fiscale: 9, Kilométrage: 290.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.207008361816406 | Real price: 44.0 | diff: 15.207008361816406
# -------
# The car is: Brand - Volkswagen, Model - Polo_Sedan
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 5, Kilométrage: 150.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 57.37229919433594 | Real price: 46.5 | diff: 10.872299194335938
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_E
# Features: Boite vitesse: True, Cylindrée: 1.499, Puissance fiscale: 9, Kilométrage: 15.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 194.38706970214844 | Real price: 248.0 | diff: 53.61293029785156
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: True, Cylindrée: 1.0, Puissance fiscale: 4, Kilométrage: 92.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 65.46407318115234 | Real price: 46.0 | diff: 19.464073181152344
# -------
# The car is: Brand - Bmw, Model - Série_3_Gt
# Features: Boite vitesse: False, Cylindrée: 2.0, Puissance fiscale: 7, Kilométrage: 176.0, Age: 10.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 52.333274841308594 | Real price: 89.0 | diff: 36.666725158691406
# -------
# The car is: Brand - Bmw, Model - Serie_1
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 170.0, Age: 12.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 62.686100006103516 | Real price: 52.0 | diff: 10.686100006103516
# -------
# The car is: Brand - Bmw, Model - Série_3
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 9, Kilométrage: 80.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 151.37937927246094 | Real price: 174.0 | diff: 22.620620727539062
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C
# Features: Boite vitesse: True, Cylindrée: 1.8, Puissance fiscale: 8, Kilométrage: 12.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 183.87486267089844 | Real price: 105.0 | diff: 78.87486267089844
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Evoque
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 13, Kilométrage: 43.0, Age: 3.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 237.52099609375 | Real price: 205.0 | diff: 32.52099609375
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C_Coupé
# Features: Boite vitesse: True, Cylindrée: 1.599, Puissance fiscale: 9, Kilométrage: 40.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 141.94598388671875 | Real price: 179.0 | diff: 37.05401611328125
# -------
# The car is: Brand - Dfsk, Model - K01h
# Features: Boite vitesse: False, Cylindrée: 1.05, Puissance fiscale: 6, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 55.528507232666016 | Real price: 37.9 | diff: 17.628507232666017
# -------
# The car is: Brand - Seat, Model - Leon
# Features: Boite vitesse: True, Cylindrée: 1.395, Puissance fiscale: 8, Kilométrage: 70.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 108.95503997802734 | Real price: 122.8 | diff: 13.844960021972653
# -------
# The car is: Brand - Fiat, Model - 500
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 4, Kilométrage: 9.0, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 48.77232360839844 | Real price: 70.0 | diff: 21.227676391601562
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C
# Features: Boite vitesse: True, Cylindrée: 1.496, Puissance fiscale: 9, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 215.9425048828125 | Real price: 261.0 | diff: 45.0574951171875
# -------
# The car is: Brand - Citroen, Model - Berlingo
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 5, Kilométrage: 220.0, Age: 12.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 34.285160064697266 | Real price: 48.0 | diff: 13.714839935302734
# -------
# The car is: Brand - Kia, Model - Picanto
# Features: Boite vitesse: True, Cylindrée: 1.0, Puissance fiscale: 41, Kilométrage: 121.0, Age: 6.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 250.08103942871094 | Real price: 41.0 | diff: 209.08103942871094
# -------
# The car is: Brand - Volkswagen, Model - Passat
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 6, Kilométrage: 160.0, Age: 5.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 85.9260025024414 | Real price: 75.0 | diff: 10.926002502441406
# -------
# The car is: Brand - Fiat, Model - Doblo
# Features: Boite vitesse: False, Cylindrée: 1.3, Puissance fiscale: 5, Kilométrage: 345.0, Age: 8.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 32.0844612121582 | Real price: 16.5 | diff: 15.584461212158203
# -------
# The car is: Brand - Kia, Model - Rio
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 80.0, Age: 4.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 54.31308364868164 | Real price: 65.0 | diff: 10.68691635131836
# -------
# The car is: Brand - Volkswagen, Model - Caddy
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 8, Kilométrage: 259.0, Age: 22.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 31.578142166137695 | Real price: 12.0 | diff: 19.578142166137695
# -------
# The car is: Brand - Kia, Model - Picanto
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 4, Kilométrage: 63.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 71.88916015625 | Real price: 54.5 | diff: 17.38916015625
# -------
# The car is: Brand - Kia, Model - Sorento
# Features: Boite vitesse: True, Cylindrée: 2.2, Puissance fiscale: 11, Kilométrage: 50.5, Age: 3.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 201.68896484375 | Real price: 190.0 | diff: 11.68896484375
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Sport
# Features: Boite vitesse: True, Cylindrée: 2.997, Puissance fiscale: 25, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 764.8970336914062 | Real price: 647.0 | diff: 117.89703369140625
# -------
# The car is: Brand - Toyota, Model - Prado
# Features: Boite vitesse: False, Cylindrée: 6.0, Puissance fiscale: 10, Kilométrage: 330.0, Age: 25.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 46.60036849975586 | Real price: 65.0 | diff: 18.39963150024414
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C_Coupe
# Features: Boite vitesse: True, Cylindrée: 2.2, Puissance fiscale: 10, Kilométrage: 247.0, Age: 16.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 66.69039916992188 | Real price: 45.0 | diff: 21.690399169921875
# -------
# The car is: Brand - Volkswagen, Model - Golf
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 110.0, Age: 9.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 46.66730499267578 | Real price: 58.5 | diff: 11.832695007324219
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_E
# Features: Boite vitesse: True, Cylindrée: 2.2, Puissance fiscale: 10, Kilométrage: 250.0, Age: 12.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 80.35347747802734 | Real price: 70.0 | diff: 10.353477478027344
# -------
# The car is: Brand - Audi, Model - A5_Sportback
# Features: Boite vitesse: True, Cylindrée: 1.395, Puissance fiscale: 8, Kilométrage: 119.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 94.66310119628906 | Real price: 107.0 | diff: 12.336898803710938
# -------
# The car is: Brand - Peugeot, Model - Partner
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 5, Kilométrage: 90.0, Age: 5.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 62.71357345581055 | Real price: 48.0 | diff: 14.713573455810547
# -------
# The car is: Brand - Suzuki, Model - Jimny
# Features: Boite vitesse: True, Cylindrée: 1.462, Puissance fiscale: 6, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 89.94432067871094 | Real price: 104.9 | diff: 14.955679321289068
# -------
# The car is: Brand - Fiat, Model - Doblo
# Features: Boite vitesse: False, Cylindrée: 3.03, Puissance fiscale: 5, Kilométrage: 15.0, Age: 7.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 62.73064422607422 | Real price: 27.5 | diff: 35.23064422607422
# -------
# The car is: Brand - Ssangyong, Model - Actyon
# Features: Boite vitesse: False, Cylindrée: 2.0, Puissance fiscale: 7, Kilométrage: 190.0, Age: 6.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 67.30361938476562 | Real price: 50.0 | diff: 17.303619384765625
# -------
# The car is: Brand - Toyota, Model - C_Hr
# Features: Boite vitesse: True, Cylindrée: 1.7, Puissance fiscale: 5, Kilométrage: 16.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 110.52691650390625 | Real price: 148.0 | diff: 37.47308349609375
# -------
# The car is: Brand - Mercedes_Benz, Model - Cla
# Features: Boite vitesse: True, Cylindrée: 1.299, Puissance fiscale: 7, Kilométrage: 59.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 103.27117919921875 | Real price: 134.9 | diff: 31.628820800781256
# -------
# The car is: Brand - Audi, Model - Q5
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 10, Kilométrage: 380.0, Age: 15.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 56.812347412109375 | Real price: 70.0 | diff: 13.187652587890625
# -------
# The car is: Brand - Suzuki, Model - Sj_Samurai
# Features: Boite vitesse: False, Cylindrée: 1.3, Puissance fiscale: 5, Kilométrage: 470.0, Age: 40.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 34.96580505371094 | Real price: 17.0 | diff: 17.965805053710938
# -------
# The car is: Brand - Bmw, Model - Serie_1
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 77.0, Age: 14.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.68055725097656 | Real price: 40.0 | diff: 19.680557250976562
# -------
# The car is: Brand - Land_Rover, Model - Range_Rover_Evoque
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 15, Kilométrage: 106.0, Age: 8.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 116.91502380371094 | Real price: 97.998 | diff: 18.917023803710933
# -------
# The car is: Brand - Peugeot, Model - Traveller
# Features: Boite vitesse: False, Cylindrée: 1.997, Puissance fiscale: 8, Kilométrage: 0.0, Age: 0.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 142.0272216796875 | Real price: 171.9 | diff: 29.872778320312506
# -------
# The car is: Brand - Peugeot, Model - 508
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 230.0, Age: 12.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 46.7249755859375 | Real price: 31.0 | diff: 15.7249755859375
# -------
# The car is: Brand - Mercedes_Benz, Model - Gle_Coupé
# Features: Boite vitesse: True, Cylindrée: 2.996, Puissance fiscale: 26, Kilométrage: 40.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 306.0924072265625 | Real price: 410.0 | diff: 103.9075927734375
# -------
# The car is: Brand - Peugeot, Model - Bipper
# Features: Boite vitesse: False, Cylindrée: 1.9, Puissance fiscale: 6, Kilométrage: 100.0, Age: 1.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 81.92786407470703 | Real price: 69.8 | diff: 12.127864074707034
# -------
# The car is: Brand - Ford, Model - Ranger
# Features: Boite vitesse: True, Cylindrée: 1.996, Puissance fiscale: 7, Kilométrage: 0.0, Age: 0.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 193.97117614746094 | Real price: 170.0 | diff: 23.971176147460938
# -------
# The car is: Brand - Bmw, Model - Série_4_Gran_Coupé
# Features: Boite vitesse: True, Cylindrée: 1.499, Puissance fiscale: 7, Kilométrage: 108.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 83.70175170898438 | Real price: 105.0 | diff: 21.298248291015625
# -------
# The car is: Brand - Ford, Model - Ranger
# Features: Boite vitesse: False, Cylindrée: 4.0, Puissance fiscale: 12, Kilométrage: 300.0, Age: 18.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 41.6613655090332 | Real price: 28.0 | diff: 13.661365509033203
# -------
# The car is: Brand - Peugeot, Model - 208
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 96.2, Age: 12.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 44.54437255859375 | Real price: 26.5 | diff: 18.04437255859375
# -------
# The car is: Brand - Peugeot, Model - Expert
# Features: Boite vitesse: False, Cylindrée: 2.0, Puissance fiscale: 7, Kilométrage: 200.0, Age: 3.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 73.75247955322266 | Real price: 59.0 | diff: 14.752479553222656
# -------
# The car is: Brand - Volkswagen, Model - Golf_8
# Features: Boite vitesse: True, Cylindrée: 1.468, Puissance fiscale: 6, Kilométrage: 102.0, Age: 3.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 89.09468841552734 | Real price: 127.0 | diff: 37.905311584472656
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 111.111, Age: 14.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 43.415767669677734 | Real price: 24.0 | diff: 19.415767669677734
# -------
# The car is: Brand - Mercedes_Benz, Model - Cla
# Features: Boite vitesse: True, Cylindrée: 1.422, Puissance fiscale: 9, Kilométrage: 190.0, Age: 9.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 100.97425079345703 | Real price: 60.0 | diff: 40.97425079345703
# -------
# The car is: Brand - Volkswagen, Model - Golf_7
# Features: Boite vitesse: True, Cylindrée: 1.2, Puissance fiscale: 6, Kilométrage: 170.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 67.1043701171875 | Real price: 57.0 | diff: 10.1043701171875
# -------
# The car is: Brand - Mercedes_Benz, Model - Ml
# Features: Boite vitesse: True, Cylindrée: 2.998, Puissance fiscale: 15, Kilométrage: 237.0, Age: 18.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 81.4665756225586 | Real price: 56.0 | diff: 25.466575622558594
# -------
# The car is: Brand - Peugeot, Model - Partner
# Features: Boite vitesse: False, Cylindrée: 1.9, Puissance fiscale: 7, Kilométrage: 243.0, Age: 11.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 33.80143737792969 | Real price: 220.0 | diff: 186.1985626220703
# -------
# The car is: Brand - Bmw, Model - X4
# Features: Boite vitesse: True, Cylindrée: 1.998, Puissance fiscale: 16, Kilométrage: 110.0, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 181.14346313476562 | Real price: 230.0 | diff: 48.856536865234375
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.4, Puissance fiscale: 5, Kilométrage: 75.0, Age: 7.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 59.27458190917969 | Real price: 39.0 | diff: 20.274581909179688
# -------
# The car is: Brand - Bmw, Model - Serie_5
# Features: Boite vitesse: True, Cylindrée: 1.999, Puissance fiscale: 11, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 358.8351135253906 | Real price: 293.9 | diff: 64.93511352539065
# -------
# The car is: Brand - Fiat, Model - Doblo
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 5, Kilométrage: 230.0, Age: 8.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 41.8741340637207 | Real price: 24.0 | diff: 17.874134063720703
# -------
# The car is: Brand - Mg, Model - 5
# Features: Boite vitesse: False, Cylindrée: 1.498, Puissance fiscale: 6, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 55.83191680908203 | Real price: 67.45 | diff: 11.618083190917972
# -------
# The car is: Brand - Suzuki, Model - Swift
# Features: Boite vitesse: True, Cylindrée: 3.0, Puissance fiscale: 5, Kilométrage: 80.0, Age: 4.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 73.93580627441406 | Real price: 46.0 | diff: 27.935806274414062
# -------
# The car is: Brand - Geely, Model - Gx3
# Features: Boite vitesse: True, Cylindrée: 1.498, Puissance fiscale: 6, Kilométrage: 77.0, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 69.63968658447266 | Real price: 47.0 | diff: 22.639686584472656
# -------
# The car is: Brand - Bmw, Model - X6
# Features: Boite vitesse: True, Cylindrée: 3.498, Puissance fiscale: 22, Kilométrage: 146.0, Age: 16.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 98.17698669433594 | Real price: 65.0 | diff: 33.17698669433594
# -------
# The car is: Brand - Seat, Model - Ateca
# Features: Boite vitesse: True, Cylindrée: 1.395, Puissance fiscale: 8, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 136.1251678466797 | Real price: 124.98 | diff: 11.145167846679684
# -------
# The car is: Brand - Chery, Model - Tiggo_7
# Features: Boite vitesse: True, Cylindrée: 1.498, Puissance fiscale: 9, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 127.45925903320312 | Real price: 99.58 | diff: 27.879259033203127
# -------
# The car is: Brand - Skoda, Model - Favorit
# Features: Boite vitesse: True, Cylindrée: 1.0, Puissance fiscale: 6, Kilométrage: 13.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 83.83869934082031 | Real price: 96.0 | diff: 12.161300659179688
# -------
# The car is: Brand - Volkswagen, Model - Polo
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 4, Kilométrage: 84.2, Age: 3.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 56.11813735961914 | Real price: 39.7 | diff: 16.418137359619138
# -------
# The car is: Brand - Mazda, Model - 6
# Features: Boite vitesse: True, Cylindrée: 1.4, Puissance fiscale: 9, Kilométrage: 215.0, Age: 11.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 45.61469650268555 | Real price: 35.0 | diff: 10.614696502685547
# -------
# The car is: Brand - Seat, Model - Leon
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 5, Kilométrage: 270.0, Age: 11.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 26.636432647705078 | Real price: 39.0 | diff: 12.363567352294922
# -------
# The car is: Brand - Mercedes_Benz, Model - Classe_C
# Features: Boite vitesse: True, Cylindrée: 1.496, Puissance fiscale: 9, Kilométrage: 35.0, Age: 2.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 169.83372497558594 | Real price: 215.0 | diff: 45.16627502441406
# -------
# The car is: Brand - Volkswagen, Model - Jetta
# Features: Boite vitesse: False, Cylindrée: 1.9, Puissance fiscale: 6, Kilométrage: 211.0, Age: 14.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 47.31012725830078 | Real price: 33.0 | diff: 14.310127258300781
# -------
# The car is: Brand - Volkswagen, Model - Passat_Cc
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 1.234, Age: 15.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 42.78890609741211 | Real price: 12.345 | diff: 30.44390609741211
# -------
# The car is: Brand - Volkswagen, Model - Jetta
# Features: Boite vitesse: False, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 179.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 71.0555419921875 | Real price: 58.0 | diff: 13.0555419921875
# -------
# The car is: Brand - Kia, Model - Picanto
# Features: Boite vitesse: True, Cylindrée: 1.197, Puissance fiscale: 4, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 82.83247375488281 | Real price: 65.48 | diff: 17.35247375488281
# -------
# The car is: Brand - Kia, Model - Stonic
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 6, Kilométrage: 25.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 84.72360229492188 | Real price: 119.485 | diff: 34.761397705078124
# -------
# The car is: Brand - Bmw, Model - Serie_3
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 9, Kilométrage: 248.0, Age: 17.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 54.91087341308594 | Real price: 33.5 | diff: 21.410873413085938
# -------
# The car is: Brand - Mercedes_Benz, Model - Cla
# Features: Boite vitesse: True, Cylindrée: 1.595, Puissance fiscale: 7, Kilométrage: 200.0, Age: 9.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 79.22242736816406 | Real price: 66.0 | diff: 13.222427368164062
# -------
# The car is: Brand - Audi, Model - A1_Sportback
# Features: Boite vitesse: True, Cylindrée: 1.395, Puissance fiscale: 6, Kilométrage: 47.5, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 79.55486297607422 | Real price: 69.0 | diff: 10.554862976074219
# -------
# The car is: Brand - Bmw, Model - Serie_5
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 10, Kilométrage: 106.0, Age: 6.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 118.20918273925781 | Real price: 148.0 | diff: 29.790817260742188
# -------
# The car is: Brand - Seat, Model - Leon
# Features: Boite vitesse: False, Cylindrée: 1.2, Puissance fiscale: 6, Kilométrage: 99.5, Age: 5.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 51.921382904052734 | Real price: 63.0 | diff: 11.078617095947266
# -------
# The car is: Brand - Ford, Model - Ecosport
# Features: Boite vitesse: False, Cylindrée: 1.0, Puissance fiscale: 7, Kilométrage: 20.0, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 61.22571563720703 | Real price: 75.0 | diff: 13.774284362792969
# -------
# The car is: Brand - Renault, Model - Grand_Scenic
# Features: Boite vitesse: True, Cylindrée: 1.5, Puissance fiscale: 6, Kilométrage: 250.0, Age: 11.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 52.299556732177734 | Real price: 37.0 | diff: 15.299556732177734
# -------
# The car is: Brand - Mg, Model - One
# Features: Boite vitesse: True, Cylindrée: 1.49, Puissance fiscale: 10, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 137.2060546875 | Real price: 103.95 | diff: 33.2560546875
# -------
# The car is: Brand - Opel, Model - Astra
# Features: Boite vitesse: True, Cylindrée: 1.199, Puissance fiscale: 7, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 91.83331298828125 | Real price: 105.9 | diff: 14.066687011718756
# -------
# The car is: Brand - Mercedes_Benz, Model - Cla
# Features: Boite vitesse: True, Cylindrée: 1.3, Puissance fiscale: 7, Kilométrage: 30.0, Age: 1.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 131.32693481445312 | Real price: 188.0 | diff: 56.673065185546875
# -------
# The car is: Brand - Mg, Model - Gt
# Features: Boite vitesse: True, Cylindrée: 1.498, Puissance fiscale: 9, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 133.00111389160156 | Real price: 95.45 | diff: 37.55111389160156
# -------
# The car is: Brand - Bmw, Model - X5
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 13, Kilométrage: 170.0, Age: 9.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 115.74559020996094 | Real price: 148.0 | diff: 32.25440979003906
# -------
# The car is: Brand - Bmw, Model - Serie_5
# Features: Boite vitesse: True, Cylindrée: 2.0, Puissance fiscale: 10, Kilométrage: 118.0, Age: 11.0, Essence: True, Diesel: False, Electric: False
# Predicted price: 71.9088363647461 | Real price: 108.0 | diff: 36.091163635253906
# -------
# The car is: Brand - Hyundai, Model - Tucson
# Features: Boite vitesse: True, Cylindrée: 1.6, Puissance fiscale: 7, Kilométrage: 150.0, Age: 5.0, Essence: False, Diesel: True, Electric: False
# Predicted price: 93.6128921508789 | Real price: 104.0 | diff: 10.387107849121094
# -------
# The car is: Brand - Toyota, Model - Yaris_Cross
# Features: Boite vitesse: True, Cylindrée: 1.49, Puissance fiscale: 5, Kilométrage: 0.0, Age: 0.0, Essence: True, Diesel: False, Electric: True
# Predicted price: 100.1814193725586 | Real price: 117.9 | diff: 17.718580627441412
# -------
